# %%
import pandas as pd
import openpyxl
from pandas import ExcelWriter
import xlsxwriter

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame()

# %%
df['Pastor']=np.random.randint(100, size=7)
df['Tripas']=np.random.randint(100, size=7)
df['Chorizo']=np.random.randint(100, size=7)

df.index=['Lunes','Martes','Miercoles','Jueves','Viernes','Sabado','Domingo']
df
# Out:
#            Pastor  Tripas  Chorizo
# Lunes          98      86       33
# Martes         12      58       36
# Miercoles      32      41       20
# Jueves         85       9       72
# Viernes        89      14       40
# Sabado         43      54       87
# Domingo         1       9       55

# %%
df.describe()
# Out:
#           Pastor     Tripas    Chorizo
# count   7.000000   7.000000   7.000000
# mean   51.428571  38.714286  49.000000
# std    39.271946  29.505447  23.650229
# min     1.000000   9.000000  20.000000
# 25%    22.000000  11.500000  34.500000
# 50%    43.000000  41.000000  40.000000
# 75%    87.000000  56.000000  63.500000
# max    98.000000  86.000000  87.000000

# %%
df['Pastor'].describe()
# Out:
# count     7.000000
# mean     51.428571
# std      39.271946
# min       1.000000
# 25%      22.000000
# 50%      43.000000
# 75%      87.000000
# max      98.000000
# Name: Pastor, dtype: float64

# %%
df.ix['Lunes']
# Out:
# Pastor     98
# Tripas     86
# Chorizo    33
# Name: Lunes, dtype: int32

# %%
df.ix['Lunes'].describe()
# Out:
# count     3.000000
# mean     72.333333
# std      34.588052
# min      33.000000
# 25%      59.500000
# 50%      86.000000
# 75%      92.000000
# max      98.000000
# Name: Lunes, dtype: float64

# %%
df.boxplot()
print("--Boxes--")
# Out:
# --Boxes--

# %%
df['Tacos Total']=df['Pastor']+df['Tripas']
df
# Out:
#            Pastor  Tripas  Chorizo  Tacos Total
# Lunes          98      86       33          184
# Martes         12      58       36           70
# Miercoles      32      41       20           73
# Jueves         85       9       72           94
# Viernes        89      14       40          103
# Sabado         43      54       87           97
# Domingo         1       9       55           10

# %%
df=df.drop("Tripas", axis=1)
df
# Out:
#            Pastor  Chorizo  Tacos Total
# Lunes          98       33          184
# Martes         12       36           70
# Miercoles      32       20           73
# Jueves         85       72           94
# Viernes        89       40          103
# Sabado         43       87           97
# Domingo         1       55           10

# %%
df.to_csv("Tacos.csv")

# %%
df1=df.from_csv("Tacos.csv")

# %%
df1
# Out:
#            Pastor  Chorizo  Tacos Total
# Lunes          98       33          184
# Martes         12       36           70
# Miercoles      32       20           73
# Jueves         85       72           94
# Viernes        89       40          103
# Sabado         43       87           97
# Domingo         1       55           10

# %%
writer = pd.ExcelWriter('Tacos.xlsx', engine='xlsxwriter')
df.to_excel(writer)

# %%
df2 = pd.read_excel( r'Tacos.xlsx', 0)
df2
# Out:
#            Pastor  Chorizo  Tacos Total
# Lunes          33       72           73
# Martes         95       62          193
# Miercoles      58       88           65
# Jueves         45       75           47
# Viernes        50       94           56
# Sabado         88       77          139
# Domingo        22       98           25

# %%
xurl="http://spreadsheets.google.com/pub?key=phAwcNAVuyj2tPLxKvvnNPA&output=xls"
df3=pd.read_excel(xurl)
print("El tamaño completo es %s"%str(df3.shape))
df3.head()
# Out:
# El tamaño completo es (244, 206)
#   Life expectancy with projections. Yellow is IHME     1800       1801  \
# 0                                      Afghanistan  28.2110  28.200753
# 1                                          Albania  35.4000  35.400000
# 2                                          Algeria  28.8224  28.822400
# 3                                   American Samoa      NaN        NaN
# 4                                          Andorra      NaN        NaN
#
#         1802      1803       1804       1805      1806       1807       1808  \
# 0  28.190507  28.18026  28.170013  28.159767  28.14952  28.139273  28.129027
# 1  35.400000  35.40000  35.400000  35.400000  35.40000  35.400000  35.400000
# 2  28.822400  28.82240  28.822400  28.822400  28.82240  28.822400  28.822400
# 3        NaN       NaN        NaN        NaN       NaN        NaN        NaN
# 4        NaN       NaN        NaN        NaN       NaN        NaN        NaN
#
# ...

# %%
df3.index=df3['Life expectancy with projections. Yellow is IHME']
df3.head()
# Out:
#                                                  Life expectancy with projections. Yellow is IHME  \
# Life expectancy with projections. Yellow is IHME
# Afghanistan                                                                           Afghanistan
# Albania                                                                                   Albania
# Algeria                                                                                   Algeria
# American Samoa                                                                     American Samoa
# Andorra                                                                                   Andorra
#
#                                                      1800       1801  \
# Life expectancy with projections. Yellow is IHME
# Afghanistan                                       28.2110  28.200753
# Albania                                           35.4000  35.400000
# Algeria                                           28.8224  28.822400
# ...

# %%
df3=df3.drop('Life expectancy with projections. Yellow is IHME',axis=1)
df3.head()
# Out:
#                                                      1800       1801  \
# Life expectancy with projections. Yellow is IHME
# Afghanistan                                       28.2110  28.200753
# Albania                                           35.4000  35.400000
# Algeria                                           28.8224  28.822400
# American Samoa                                        NaN        NaN
# Andorra                                               NaN        NaN
#
#                                                        1802      1803  \
# Life expectancy with projections. Yellow is IHME
# Afghanistan                                       28.190507  28.18026
# Albania                                           35.400000  35.40000
# Algeria                                           28.822400  28.82240
# American Samoa                                          NaN       NaN
# Andorra                                                 NaN       NaN
#
# ...

# %%
df3=df3.transpose()
df3.head()
# Out:
# Life expectancy with projections. Yellow is IHME  Afghanistan  Albania  \
# 1800                                                28.211000     35.4
# 1801                                                28.200753     35.4
# 1802                                                28.190507     35.4
# 1803                                                28.180260     35.4
# 1804                                                28.170013     35.4
#
# Life expectancy with projections. Yellow is IHME  Algeria  American Samoa  \
# 1800                                              28.8224             NaN
# 1801                                              28.8224             NaN
# 1802                                              28.8224             NaN
# 1803                                              28.8224             NaN
# 1804                                              28.8224             NaN
#
# Life expectancy with projections. Yellow is IHME  Andorra  Angola  Anguilla  \
# ...

# %% [markdown]
# Hola mundo!!!

# %%
df3['Mexico'].plot()
print("==Esperanza de vida en México==")
plt.grid()
# Out:
# ==Esperanza de vida en México==

# %%
subdf=df3[df3.index >= 1890]
subdf=subdf[ subdf.index <= 1955]
subdf['Mexico'].plot()
plt.grid()
print("== Esperanza de Vida en Mexico entre 1890 y 1955 ==")
# Out:
# == Esperanza de Vida en Mexico entre 1890 y 1955 ==

# %%
df3[['Mexico', 'United States', 'Canada']].plot()
plt.grid()
print("== Esperanza de Vida en Norte-America ==")
# Out:
# == Esperanza de Vida en Norte-America ==

# %%
LatinoA=['Mexico', 'Guatemala','Paraguay', 'Argentina', 'Brazil']
subdf=df3[df3.index >= 1900]
subdf=subdf[ subdf.index <= 2000]
subdf[LatinoA].plot()
plt.grid()
print("== Esperanza de Vida en Latino-America1 ==")
# Out:
# == Esperanza de Vida en Latino-America1 ==

# %%
df3=df3.dropna(axis=1)
df3.head()
# Out:
# Life expectancy with projections. Yellow is IHME  Afghanistan  Albania  \
# 1800                                                28.211000     35.4
# 1801                                                28.200753     35.4
# 1802                                                28.190507     35.4
# 1803                                                28.180260     35.4
# 1804                                                28.170013     35.4
#
# Life expectancy with projections. Yellow is IHME  Algeria  Angola  \
# 1800                                              28.8224   26.98
# 1801                                              28.8224   26.98
# 1802                                              28.8224   26.98
# 1803                                              28.8224   26.98
# 1804                                              28.8224   26.98
#
# Life expectancy with projections. Yellow is IHME  Antigua and Barbuda  \
# ...

# %%
df3['Mexico'].describe()
# Out:
# count    205.000000
# mean      39.144305
# std       17.360456
# min       18.186424
# 25%       26.900000
# 50%       27.580000
# 75%       51.254000
# max       76.200000
# Name: Mexico, dtype: float64

# %%
subdf=df3[df3.index>=1800]
subdf= subdf[subdf.index<=1900]
subdf['Mexico'].describe()
# Out:
# count    101.00000
# mean      26.85297
# std        0.59332
# min       23.29000
# 25%       26.90000
# 50%       26.90000
# 75%       26.90000
# max       29.52000
# Name: Mexico, dtype: float64
